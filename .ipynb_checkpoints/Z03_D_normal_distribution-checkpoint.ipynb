# %% [markdown]
# # 2-wymiarowy rozkład Normalny

# %%
import matplotlib.pyplot as plt
import numpy as np
import numpy.random as rnd
import scipy.stats as stats
from scipy.stats import multivariate_normal

# %% [markdown]
# # Zadanie
# Proszę wygenerować próbkę z rozkładu Normalnego
# $$
# m = [0,0]
# $$
#
# oraz
#
# $$
# \Sigma = [[4.40, -2.75], [-2.75,  5.50]]
# $$

# %%
mean1 = np.array([0, 0])
cov1 = np.array([[4.40, -2.75], [-2.75,  5.50]])
X1_rv=multivariate_normal(mean1, cov1)
X = X1_rv.rvs(1000)

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(5, 5))
ax.scatter(X[:, 0], X[:, 1])
ax.set_xlim([-10,10])
ax.set_ylim([-10,10])
plt.show()

# %% [markdown]
# # Zadanie
# Proszę policzyć średnią oraz macierz kowariancji próbki.

# %%
means = X.mean(axis=0)
cov = np.cov(X.T)
# Out:
# array([ 0.05591346, -0.13032734])

# %% [markdown]
# # Zadanie
# Proszę zdefiniować zmienną losową o razkładzie zadanym na podstawie empirycznej średniej i kowariancji oraz narysować na jednym wykresie:
#
# - próbkę
# - poziomice rozkładu normalnego

# %%
X2_rv=multivariate_normal(means, cov)

# %%
X2 = X2_rv.rvs(1000)
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(5, 5))
ax.scatter(X2[:, 0], X2[:, 1])
x_axis = np.linspace(-10,10,500)
y_axis = np.linspace(-10,10,500)
X, Y = np.meshgrid(x_axis,y_axis)
pos = np.dstack((X,Y))
ax.contour(X, Y, X2_rv.pdf(pos))

plt.show()

# %% [markdown]
# # Zadanie
# Policz wektory i wartości własne macierzy kowariancji. Narysuj na jednym wykresie
#
# - próbkę
# - poziomice rozkładu normalnego
# - wektory własne macierzy kowariancji

# %%
X2 = X2_rv.rvs(1000)
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(5, 5))
ax.scatter(X2[:, 0], X2[:, 1])
x_axis = np.linspace(-10,10,500)
y_axis = np.linspace(-10,10,500)
X, Y = np.meshgrid(x_axis,y_axis)
pos = np.dstack((X,Y))
ax.contour(X, Y, X2_rv.pdf(pos))
cov1 = np.array([[4.40, -2.75], [-2.75,  5.50]])
w, v = np.linalg.eig(cov1)
print(xd)
x = [v[0,0],0,v[0,1]]
y = [v[1,0],0,v[1,1]]
ax.plot(x,y,c='r')
##ax.plot(mean1,cov1[:,0])
##plt.show()
# Out:
# [[-0.77334214  0.63398891]
#  [-0.63398891 -0.77334214]]

# %% [markdown]
# # Zadanie
# Proszę wygenerować próbkę na kwadracie $[0,1] \times [0,1]$.
# Następnie proszę policzyć średnią oraz macierz kowariancji próbki.
#
# Narysuj na jednym wykresie
#
# - próbkę
# - poziomice rozkładu normalnego
# - wektory własne macierzy kowariancji

# %%
x = np.random.uniform(0,1,1000)
y = np.random.uniform(0,1,1000)
data =[x,y]
mean = np.mean(data,1)
cov = np.cov(data)

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(5, 5))
ax.scatter(x, y)
x_axis = np.linspace(-0.2,1.2,500)
y_axis = np.linspace(-0.2,1.2,500)

X1_rv=multivariate_normal(mean, cov)
X = X1_rv.rvs(1000)
X, Y = np.meshgrid(x_axis,y_axis)
pos = np.dstack((X,Y))
ax.contour(X, Y, X1_rv.pdf(pos))
w, v = np.linalg.eig(cov)
x = [v[0,0],0.5,v[1,0]]
y = [v[0,1],0.5,v[1,1]]
ax.plot(x,y,c='r')
